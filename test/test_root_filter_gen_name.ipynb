# %%
datapath='../data/radbkg/data-fixed/radiological_decay0_dunevd10kt_1x8x6_patched_wall_gammas_2337894_9_evfix_ana.ntuple.root'
datapath='../data/radbkg/data-fixed/*_ana.ntuple.root'

# %%
import ROOT

# %%
ROOT.EnableImplicitMT()

rdf_mct = ROOT.RDataFrame(f'triggerAna/mctruths', datapath)

# %%
h_x = rdf_mct.Filter('generator_name == "CavernwallGammasAtLAr1x8x6"').Histo1D('kinetic_energy')

# %%
c1 = ROOT.TCanvas()

# %%
h_x.DrawClone()

# %%
c1.Draw()

# %%
c1.SetLogy()

# %%
c1.Draw()
