# %%
import ROOT


c1 = ROOT.TCanvas()
c1.Draw()
# Out:
# Error in callback <bound method CaptureDrawnPrimitives._post_execute of <JupyROOT.helpers.utils.CaptureDrawnPrimitives object at 0x7f7855b0ea20>> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/devel/dune-trigger/root-test/.venv/lib/python3.12/site-packages/JupyROOT/helpers/utils.py:501, in CaptureDrawnPrimitives._post_execute(self)
#     500 def _post_execute(self):
# --> 501     NotebookDraw()
#
# File ~/devel/dune-trigger/root-test/.venv/lib/python3.12/site-packages/JupyROOT/helpers/utils.py:488, in NotebookDraw()
#     486 def NotebookDraw():
#     487     DrawGeometry()
# --> 488     DrawCanvases()
#     489     DrawRCanvases()
#
# File ~/devel/dune-trigger/root-test/.venv/lib/python3.12/site-packages/JupyROOT/helpers/utils.py:477, in DrawCanvases()
#     475 drawers = GetCanvasDrawers()
# ...

# %%
c = ROOT.TWebCanvas

# %%
ROOT.TWebCanvas
# Out:
# <class cppyy.gbl.TWebCanvas at 0x7fb9660>

# %%
from cppyy.gbl import TWebCanvas
# Out:
# Error in callback <bound method CaptureDrawnPrimitives._post_execute of <JupyROOT.helpers.utils.CaptureDrawnPrimitives object at 0x7f7855b0ea20>> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/devel/dune-trigger/root-test/.venv/lib/python3.12/site-packages/JupyROOT/helpers/utils.py:501, in CaptureDrawnPrimitives._post_execute(self)
#     500 def _post_execute(self):
# --> 501     NotebookDraw()
#
# File ~/devel/dune-trigger/root-test/.venv/lib/python3.12/site-packages/JupyROOT/helpers/utils.py:488, in NotebookDraw()
#     486 def NotebookDraw():
#     487     DrawGeometry()
# --> 488     DrawCanvases()
#     489     DrawRCanvases()
#
# File ~/devel/dune-trigger/root-test/.venv/lib/python3.12/site-packages/JupyROOT/helpers/utils.py:477, in DrawCanvases()
#     475 drawers = GetCanvasDrawers()
# ...

# %%
TWebCanvas.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               '__dict__': <attribute '__dict__' of 'TWebCanvas' objects>,
#               '__weakref__': <attribute '__weakref__' of 'TWebCanvas' objects>,
#               '__doc__': None,
#               '__init__': <cppyy.CPPOverload at 0x7f507dd9e900>})
